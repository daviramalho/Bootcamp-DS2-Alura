# %% [markdown]
# ## Aula 01 - Entendendo Série Temporal
# ### Parte 1 - Coleta de Dados e Primeiras Análises
#
# - Fonte dos dados: [Governo do Estado de São Paulo](https://www.seade.gov.br/coronavirus/)

# %%
src = "../../data/modulo_03/dados_covid_sp.zip"

# %%
import  pandas as pd

# %%
dados = pd.read_csv(src, sep=";")

# %%
dados.head()
# Out:
#          nome_munic  codigo_ibge  dia  mes    datahora  casos  casos_novos  \
# 0        Adamantina      3500105   25    2  2020-02-25      0            0
# 1            Adolfo      3500204   25    2  2020-02-25      0            0
# 2             Aguaí      3500303   25    2  2020-02-25      0            0
# 3    Águas da Prata      3500402   25    2  2020-02-25      0            0
# 4  Águas de Lindóia      3500501   25    2  2020-02-25      0            0
#
#        casos_pc    casos_mm7d  obitos  ...               nome_drs cod_drs  \
# 0  0,000000e+00     0,0000000       0  ...                Marília       5
# 1  0,000000e+00     0,0000000       0  ...  São José do Rio Preto      15
# 2  0,000000e+00     0,0000000       0  ...  São João da Boa Vista      14
# 3  0,000000e+00     0,0000000       0  ...  São João da Boa Vista      14
# 4  0,000000e+00     0,0000000       0  ...               Campinas       3
#
#      pop pop_60   area  map_leg map_leg_s  latitude  longitude  semana_epidem
# 0  33894   7398  41199        0       8.0  -21,6820   -51,0737              9
# 1   3447    761  21106        0       8.0  -21,2325   -49,6451              9
# 2  35608   5245  47455        0       8.0  -22,0572   -46,9735              9
# 3   7797   1729  14267        0       8.0  -21,9319   -46,7176              9
# 4  18374   3275   6013        0       8.0  -22,4733   -46,6314              9
#
# [5 rows x 26 columns]

# %%
dados["datahora"] = pd.to_datetime(dados["datahora"], format="%Y-%m-%d")

# %%
import matplotlib as mpl

# %%
mpl.rcParams["font.size"] = 12
mpl.rcParams["figure.figsize"] = (15,8)

# %%
import seaborn as sns

# %%
sns.lineplot(x="datahora", y="casos", data=dados)
# Out:
# <AxesSubplot:xlabel='datahora', ylabel='casos'>

# %% [markdown]
# #### Fórmula
# $$ e^x $$

# %%
import numpy as np

# %%
eixo_x = np.linspace(-2,2,100)

# %%
y_exp = np.exp(eixo_x)

# %%
sns.lineplot(x=eixo_x, y=y_exp)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Fórmula
#
# $$ log_2 2 = 1 $$
# $$ log_2 2^x = x $$
# $$ log_e e^x = x $$

# %%
sns.lineplot(x=eixo_x, y=y_exp)
mpl.pyplot.yscale("log")

# %%
dados_sp = dados.query('nome_munic == "São Paulo"')

# %%
sns.lineplot(x="datahora",y="casos",data=dados_sp)
mpl.pyplot.yscale("log")

# %% [markdown]
# - <p style="color:red">O que é tranformação logarítmica? Qual sua utilidade para o estudo de séries temporais?</p>
#
# Diminui possíveis efeitos de viés e outliers.

# %% [markdown]
# ### DESAFIO 03.01.01: Tentar filtrar a base com alguma outra função que não o Query.

# %% [markdown]
# **Documentação Consultada:**
# - [Pandas Set Index](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.set_index.html#pandas.DataFrame.set_index)
# - [Pandas Slice data](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html)

# %%
dados=dados.set_index("nome_munic")
dados.head()
# Out:
#                   codigo_ibge  dia  mes   datahora  casos  casos_novos  \
# nome_munic
# Adamantina            3500105   25    2 2020-02-25      0            0
# Adolfo                3500204   25    2 2020-02-25      0            0
# Aguaí                 3500303   25    2 2020-02-25      0            0
# Águas da Prata        3500402   25    2 2020-02-25      0            0
# Águas de Lindóia      3500501   25    2 2020-02-25      0            0
#
#                       casos_pc    casos_mm7d  obitos  obitos_novos  ...  \
# nome_munic                                                          ...
# Adamantina        0,000000e+00     0,0000000       0             0  ...
# Adolfo            0,000000e+00     0,0000000       0             0  ...
# Aguaí             0,000000e+00     0,0000000       0             0  ...
# Águas da Prata    0,000000e+00     0,0000000       0             0  ...
# Águas de Lindóia  0,000000e+00     0,0000000       0             0  ...
#
#                                nome_drs cod_drs    pop pop_60   area map_leg  \
# nome_munic
# Adamantina                      Marília       5  33894   7398  41199       0
# Adolfo            São José do Rio Preto      15   3447    761  21106       0
# Aguaí             São João da Boa Vista      14  35608   5245  47455       0
# Águas da Prata    São João da Boa Vista      14   7797   1729  14267       0
# Águas de Lindóia               Campinas       3  18374   3275   6013       0
#
#                   map_leg_s  latitude  longitude  semana_epidem
# nome_munic
# Adamantina              8.0  -21,6820   -51,0737              9
# Adolfo                  8.0  -21,2325   -49,6451              9
# Aguaí                   8.0  -22,0572   -46,9735              9
# Águas da Prata          8.0  -21,9319   -46,7176              9
# Águas de Lindóia        8.0  -22,4733   -46,6314              9
#
# [5 rows x 25 columns]

# %%
dados.loc["São Paulo"]
# Out:
#             codigo_ibge  dia  mes   datahora   casos  casos_novos  \
# nome_munic
# São Paulo       3550308   25    2 2020-02-25       1            0
# São Paulo       3550308   26    2 2020-02-26       1            0
# São Paulo       3550308   27    2 2020-02-27       1            0
# São Paulo       3550308   28    2 2020-02-28       2            1
# São Paulo       3550308   29    2 2020-02-29       2            0
# ...                 ...  ...  ...        ...     ...          ...
# São Paulo       3550308    8    5 2021-05-08  735057         1998
# São Paulo       3550308    9    5 2021-05-09  736342         1285
# São Paulo       3550308   10    5 2021-05-10  736880          538
# São Paulo       3550308   11    5 2021-05-11  739821         2941
# São Paulo       3550308   12    5 2021-05-12  742629         2808
#
#                 casos_pc    casos_mm7d  obitos  obitos_novos  ...  \
# nome_munic                                                    ...
# São Paulo   8,424841e-03     0,0000000       0             0  ...
# São Paulo   8,424841e-03     0,0000000       0             0  ...
# São Paulo   8,424841e-03     0,0000000       0             0  ...
# São Paulo   1,684968e-02     0,0000000       0             0  ...
# São Paulo   1,684968e-02     0,0000000       0             0  ...
# ...                  ...           ...     ...           ...  ...
# São Paulo   6,192738e+03  1956,5714286   28309           178  ...
# São Paulo   6,203564e+03  2024,1428571   28347            38  ...
# São Paulo   6,208097e+03  2008,1428571   28364            17  ...
# São Paulo   6,232874e+03  2039,1428571   28583           219  ...
# São Paulo   6,256531e+03  2069,0000000   28764           181  ...
#
#                     nome_drs cod_drs       pop   pop_60    area map_leg  \
# nome_munic
# São Paulo   Grande São Paulo      10  11869660  1853286  152111     <50
# São Paulo   Grande São Paulo      10  11869660  1853286  152111     <50
# São Paulo   Grande São Paulo      10  11869660  1853286  152111     <50
# São Paulo   Grande São Paulo      10  11869660  1853286  152111     <50
# São Paulo   Grande São Paulo      10  11869660  1853286  152111     <50
# ...                      ...     ...       ...      ...     ...     ...
# São Paulo   Grande São Paulo      10  11869660  1853286  152111   >5000
# São Paulo   Grande São Paulo      10  11869660  1853286  152111   >5000
# São Paulo   Grande São Paulo      10  11869660  1853286  152111   >5000
# São Paulo   Grande São Paulo      10  11869660  1853286  152111   >5000
# São Paulo   Grande São Paulo      10  11869660  1853286  152111   >5000
#
#             map_leg_s  latitude  longitude  semana_epidem
# nome_munic
# São Paulo         7.0  -23,5329   -46,6395              9
# São Paulo         7.0  -23,5329   -46,6395              9
# São Paulo         7.0  -23,5329   -46,6395              9
# São Paulo         7.0  -23,5329   -46,6395              9
# São Paulo         7.0  -23,5329   -46,6395              9
# ...               ...       ...        ...            ...
# São Paulo         1.0  -23,5329   -46,6395             18
# São Paulo         1.0  -23,5329   -46,6395             19
# São Paulo         1.0  -23,5329   -46,6395             19
# São Paulo         1.0  -23,5329   -46,6395             19
# São Paulo         1.0  -23,5329   -46,6395             19
#
# [443 rows x 25 columns]

# %%
sns.lineplot(x="datahora", y="casos", data=dados.loc["São Paulo"])
# Out:
# <AxesSubplot:xlabel='datahora', ylabel='casos'>

# %%
sns.lineplot(x="datahora",y="casos",data=dados.loc["São Paulo"])
mpl.pyplot.yscale("log")

# %% [markdown]
# ### DESAFIO 03.01.02: Fazer a mesma análise para outro município, preferencialmente de seu estado.

# %%
dados.loc["Botucatu"]
# Out:
#             codigo_ibge  dia  mes   datahora  casos  casos_novos  \
# nome_munic
# Botucatu        3507506   25    2 2020-02-25      0            0
# Botucatu        3507506   26    2 2020-02-26      0            0
# Botucatu        3507506   27    2 2020-02-27      0            0
# Botucatu        3507506   28    2 2020-02-28      0            0
# Botucatu        3507506   29    2 2020-02-29      0            0
# ...                 ...  ...  ...        ...    ...          ...
# Botucatu        3507506    8    5 2021-05-08  11204           41
# Botucatu        3507506    9    5 2021-05-09  11214           10
# Botucatu        3507506   10    5 2021-05-10  11237           23
# Botucatu        3507506   11    5 2021-05-11  11306           69
# Botucatu        3507506   12    5 2021-05-12  11333           27
#
#                 casos_pc    casos_mm7d  obitos  obitos_novos  ... nome_drs  \
# nome_munic                                                    ...
# Botucatu    0,000000e+00     0,0000000       0             0  ...    Bauru
# Botucatu    0,000000e+00     0,0000000       0             0  ...    Bauru
# Botucatu    0,000000e+00     0,0000000       0             0  ...    Bauru
# Botucatu    0,000000e+00     0,0000000       0             0  ...    Bauru
# Botucatu    0,000000e+00     0,0000000       0             0  ...    Bauru
# ...                  ...           ...     ...           ...  ...      ...
# Botucatu    7,938499e+03    35,5714286     211             1  ...    Bauru
# Botucatu    7,945584e+03    36,2857143     211             0  ...    Bauru
# Botucatu    7,961880e+03    38,4285714     211             0  ...    Bauru
# Botucatu    8,010770e+03    38,7142857     211             0  ...    Bauru
# Botucatu    8,029900e+03    37,4285714     211             0  ...    Bauru
#
#            cod_drs     pop pop_60    area map_leg  map_leg_s  latitude  \
# nome_munic
# Botucatu        12  141135  23520  148264       0        8.0  -22,8837
# Botucatu        12  141135  23520  148264       0        8.0  -22,8837
# Botucatu        12  141135  23520  148264       0        8.0  -22,8837
# Botucatu        12  141135  23520  148264       0        8.0  -22,8837
# Botucatu        12  141135  23520  148264       0        8.0  -22,8837
# ...            ...     ...    ...     ...     ...        ...       ...
# Botucatu        12  141135  23520  148264   >5000        1.0  -22,8837
# Botucatu        12  141135  23520  148264   >5000        1.0  -22,8837
# Botucatu        12  141135  23520  148264   >5000        1.0  -22,8837
# Botucatu        12  141135  23520  148264   >5000        1.0  -22,8837
# Botucatu        12  141135  23520  148264   >5000        1.0  -22,8837
#
#             longitude  semana_epidem
# nome_munic
# Botucatu     -48,4437              9
# Botucatu     -48,4437              9
# Botucatu     -48,4437              9
# Botucatu     -48,4437              9
# Botucatu     -48,4437              9
# ...               ...            ...
# Botucatu     -48,4437             18
# Botucatu     -48,4437             19
# Botucatu     -48,4437             19
# Botucatu     -48,4437             19
# Botucatu     -48,4437             19
#
# [443 rows x 25 columns]

# %%
sns.lineplot(x="datahora", y="casos", data=dados.loc["Botucatu"])
# Out:
# <AxesSubplot:xlabel='datahora', ylabel='casos'>

# %%
sns.lineplot(x="datahora",y="casos",data=dados.loc["Botucatu"])
mpl.pyplot.yscale("log")

# %% [markdown]
# ## Aula 01 - Entendendo Série Temporal
# ### Parte 2 - Taxa de Crecimento e Média Móvel

# %%
sns.lineplot(x='datahora', y='casos_novos', data=dados_sp)
# Out:
# <AxesSubplot:xlabel='datahora', ylabel='casos_novos'>

# %%
dados_exemplo = pd.DataFrame(data=np.linspace(1,10,10))

# %%
dados_exemplo.head()
# Out:
#      0
# 0  1.0
# 1  2.0
# 2  3.0
# 3  4.0
# 4  5.0

# %%
dados_exemplo['diferenciado'] = dados_exemplo.diff()

# %%
sns.lineplot(x=0, y=0, data=dados_exemplo)
sns.lineplot(x=0, y='diferenciado', data=dados_exemplo)
# Out:
# <AxesSubplot:xlabel='0', ylabel='0'>

# %%
dados_sp['taxa_de_crescimento_casos'] = dados_sp['casos_novos'].diff()
dados_sp['taxa_de_crescimento_obitos'] = dados_sp['obitos_novos'].diff()

# %%
sns.lineplot(x='datahora', y='taxa_de_crescimento_casos', data=dados_sp)
sns.lineplot(x='datahora', y='taxa_de_crescimento_obitos', data=dados_sp)
# Out:
# <AxesSubplot:xlabel='datahora', ylabel='taxa_de_crescimento_casos'>

# %%
sns.lineplot(x='datahora', y='taxa_de_crescimento_obitos', data=dados_sp)
# Out:
# <AxesSubplot:xlabel='datahora', ylabel='taxa_de_crescimento_obitos'>

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(dados_sp['datahora'],dados_sp['taxa_de_crescimento_casos'])
# Out:
# <BarContainer object of 443 artists>

# %%
dados_sp['ano'] = pd.DatetimeIndex(dados_sp['datahora']).year

# %%
dados_2021 = dados_sp.query('ano == 2021')

# %%
plt.bar(dados_2021['datahora'], dados_2021['taxa_de_crescimento_casos'])
# Out:
# <BarContainer object of 132 artists>

# %%
dados_sp['media_movel_casos'] = dados_sp['casos_novos'].rolling(window=7,center=False).mean()
dados_sp['media_movel_obitos'] = dados_sp['obitos_novos'].rolling(window=7,center=False).mean()

# %%
sns.lineplot(x='datahora',y='casos_novos', data=dados_sp)
sns.lineplot(x='datahora', y='media_movel_casos', data=dados_sp)
# Out:
# <AxesSubplot:xlabel='datahora', ylabel='casos_novos'>

# %% [markdown]
# ### DESAFIO 03.01.03: Mostrar o notebook sem os warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### DESAFIO 03.01.04: Comparar se o pico da taxa de casos novos coincide com a taxa dos óbitos novos.

# %% [markdown]
# **Documentação consultada:**
# - [Seaborn Axes Style](https://seaborn.pydata.org/generated/seaborn.axes_style.html#seaborn.axes_style)
# - [Seaborn Set Style](https://seaborn.pydata.org/generated/seaborn.set_style.html#seaborn.set_style)

# %%
sns.lineplot(x='datahora', y='taxa_de_crescimento_casos', data=dados_sp)
sns.lineplot(x='datahora', y='taxa_de_crescimento_obitos', data=dados_sp)
sns.set_style("darkgrid")

# %% [markdown]
# ### DESAFIO 03.01.05: Melhorar todas as visualizações dos gráficos.

# %% [markdown]
# **Documentação Consultada:**
# - [Matplotlib Documentation](https://matplotlib.org/stable/tutorials/introductory/usage.html)

# %%
sns.lineplot(x='datahora',y='casos_novos', data=dados_sp)
sns.lineplot(x='datahora', y='media_movel_casos', data=dados_sp)
sns.set_style("darkgrid")
plt.xlabel("Data")
plt.ylabel("Quantidade")
plt.title("Casos Novos e Média Móvel de Casos no Município de São Paulo")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### DESAFIO 03.01.06: Gerar o gráfico da média móvel do número de óbitos. Mudar os gráficos de casos de linha para barra.

# %%
sns.lineplot(x='datahora',y='casos_novos', data=dados_sp)
sns.lineplot(x='datahora', y='media_movel_obitos', data=dados_sp)
sns.set_style("darkgrid")
plt.xlabel("Data")
plt.ylabel("Quantidade")
plt.title("Casos Novos e Média Móvel de Casos no Município de São Paulo")
#plt.legend()
plt.show()

# %%
dados_sp.head()
# Out:
#      nome_munic  codigo_ibge  dia  mes   datahora  casos  casos_novos  \
# 562   São Paulo      3550308   25    2 2020-02-25      1            0
# 1207  São Paulo      3550308   26    2 2020-02-26      1            0
# 1852  São Paulo      3550308   27    2 2020-02-27      1            0
# 2497  São Paulo      3550308   28    2 2020-02-28      2            1
# 3142  São Paulo      3550308   29    2 2020-02-29      2            0
#
#           casos_pc    casos_mm7d  obitos  ...  map_leg map_leg_s  latitude  \
# 562   8,424841e-03     0,0000000       0  ...      <50       7.0  -23,5329
# 1207  8,424841e-03     0,0000000       0  ...      <50       7.0  -23,5329
# 1852  8,424841e-03     0,0000000       0  ...      <50       7.0  -23,5329
# 2497  1,684968e-02     0,0000000       0  ...      <50       7.0  -23,5329
# 3142  1,684968e-02     0,0000000       0  ...      <50       7.0  -23,5329
#
#      longitude semana_epidem  taxa_de_crescimento_casos  \
# 562   -46,6395             9                        NaN
# 1207  -46,6395             9                        0.0
# 1852  -46,6395             9                        0.0
# 2497  -46,6395             9                        1.0
# 3142  -46,6395             9                       -1.0
#
#      taxa_de_crescimento_obitos   ano  media_movel_casos  media_movel_obitos
# 562                         NaN  2020                NaN                 NaN
# 1207                        0.0  2020                NaN                 NaN
# 1852                        0.0  2020                NaN                 NaN
# 2497                        0.0  2020                NaN                 NaN
# 3142                        0.0  2020                NaN                 NaN
#
# [5 rows x 31 columns]

# %%
plt.bar(dados_sp['datahora'],dados_sp['casos_novos'])
# Out:
# <BarContainer object of 443 artists>

# %% [markdown]
# ## Aula 01 - Entendendo Série Temporal
# ### Parte 3 - Correlação e Função de autocorrelação

# %%
sns.lineplot(x='casos_novos',y='casos_novos',data=dados_sp)
# Out:
# <AxesSubplot:xlabel='casos_novos', ylabel='casos_novos'>

# %%
sns.lineplot(x='casos_novos',y='obitos_novos',data=dados_sp)
# Out:
# <AxesSubplot:xlabel='casos_novos', ylabel='obitos_novos'>

# %%
dados_202101 = dados_sp.query('mes == 1 & ano == 2021')
dados_202102 = dados_sp.query('mes == 2 & ano == 2021')

# %%
plt.bar(np.linspace(1,31,31),dados_202101['casos_novos'])
plt.show()
plt.bar(np.linspace(1,28,28),dados_202102['casos_novos'])
# Out:
# <BarContainer object of 28 artists>

# %% [markdown]
# **Função de autocorrelação para identificar sazonalidade:**
#
# - Identifica se existe dependência temporal;
# - Em valores aleatórios não existe dependência temporal, como se pode ver no segundo gráfico a seguir.

# %%
from pandas.plotting import autocorrelation_plot

# %%
autocorrelation_plot(dados_sp['casos_novos'])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
dados_sp.shape
# Out:
# (443, 31)

# %%
aleatorio = np.random.rand(443)

# %%
autocorrelation_plot(aleatorio)
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %% [markdown]
# ### DESAFIO 03.01.07: Mover o número de obitos alguns dias para verificar se a relação entre os casos novos e os óbitos. Teste diferentes janelas de tempo (3 dias, 7 dias, 14 dias)

# %%
dados_sp_90dias = dados_sp[90:]
dados_sp_90dias
# Out:
#        nome_munic  codigo_ibge  dia  mes   datahora   casos  casos_novos  \
# 58612   São Paulo      3550308   25    5 2020-05-25   46204          677
# 59257   São Paulo      3550308   26    5 2020-05-26   47554         1350
# 59902   São Paulo      3550308   27    5 2020-05-27   49264         1710
# 60547   São Paulo      3550308   28    5 2020-05-28   52719         3455
# 61192   São Paulo      3550308   29    5 2020-05-29   55741         3022
# ...           ...          ...  ...  ...        ...     ...          ...
# 283072  São Paulo      3550308    8    5 2021-05-08  735057         1998
# 283717  São Paulo      3550308    9    5 2021-05-09  736342         1285
# 284362  São Paulo      3550308   10    5 2021-05-10  736880          538
# 285007  São Paulo      3550308   11    5 2021-05-11  739821         2941
# 285652  São Paulo      3550308   12    5 2021-05-12  742629         2808
#
#             casos_pc    casos_mm7d  obitos  ...  map_leg map_leg_s  latitude  \
# 58612   3,892614e+02  1430,8571429    3555  ...    >5000       1.0  -23,5329
# 59257   4,006349e+02  1416,2857143    3691  ...    >5000       1.0  -23,5329
# 59902   4,150414e+02  1399,7142857    3826  ...    >5000       1.0  -23,5329
# 60547   4,441492e+02  1609,7142857    3958  ...    >5000       1.0  -23,5329
# 61192   4,696091e+02  1824,0000000    4116  ...    >5000       1.0  -23,5329
# ...              ...           ...     ...  ...      ...       ...       ...
# 283072  6,192738e+03  1956,5714286   28309  ...    >5000       1.0  -23,5329
# 283717  6,203564e+03  2024,1428571   28347  ...    >5000       1.0  -23,5329
# 284362  6,208097e+03  2008,1428571   28364  ...    >5000       1.0  -23,5329
# 285007  6,232874e+03  2039,1428571   28583  ...    >5000       1.0  -23,5329
# 285652  6,256531e+03  2069,0000000   28764  ...    >5000       1.0  -23,5329
#
#        longitude semana_epidem  taxa_de_crescimento_casos  \
# 58612   -46,6395            22                       37.0
# 59257   -46,6395            22                      673.0
# 59902   -46,6395            22                      360.0
# 60547   -46,6395            22                     1745.0
# 61192   -46,6395            22                     -433.0
# ...          ...           ...                        ...
# 283072  -46,6395            18                     -515.0
# 283717  -46,6395            19                     -713.0
# 284362  -46,6395            19                     -747.0
# 285007  -46,6395            19                     2403.0
# 285652  -46,6395            19                     -133.0
#
#        taxa_de_crescimento_obitos   ano  media_movel_casos  media_movel_obitos
# 58612                       -22.0  2020        1430.857143           99.857143
# 59257                       115.0  2020        1416.285714           94.571429
# 59902                        -1.0  2020        1399.714286           98.714286
# 60547                        -3.0  2020        1609.714286          102.857143
# 61192                        26.0  2020        1824.000000          109.142857
# ...                           ...   ...                ...                 ...
# 283072                       35.0  2021        1956.571429          114.571429
# 283717                     -140.0  2021        2024.142857          116.714286
# 284362                      -21.0  2021        2008.142857          114.142857
# 285007                      202.0  2021        2039.142857          120.000000
# 285652                      -38.0  2021        2069.000000          125.142857
#
# [353 rows x 31 columns]

# %%
sns.lineplot(x='casos_novos',y='obitos_novos',data=dados_sp)
#sns.lineplot(x=dados_sp['casos_novos'],y=dados_sp_7dias['obitos_novos'])
sns.lineplot(x=dados_sp['casos_novos'],y=dados_sp_90dias['obitos_novos'])
# Out:
# <AxesSubplot:xlabel='casos_novos', ylabel='obitos_novos'>

# %% [markdown]
# ### DESAFIO 03.01.08: Calcular a função de autocorrelação cruzada dos óbitos e casos. (teste a biblioteca statsmodels)

# %% [markdown]
# **Documentação consultada:**
# - [Statsmodels Instalation](https://www.statsmodels.org/stable/install.html)
# - [Statsmodels Calculate the autocorrelation function](https://www.statsmodels.org/stable/generated/statsmodels.tsa.stattools.acf.html)
# - [Statsmodels Autocorrelation - Plot autocorrelation function](https://www.statsmodels.org/stable/generated/statsmodels.graphics.tsaplots.plot_acf.html)
# - [Statsmodels Autocorrelation - Plot partial autocorrelation function](https://www.statsmodels.org/stable/generated/statsmodels.graphics.tsaplots.plot_pacf.html)
# - [Two variables Autocorrelation Statsmodels Article](https://machinelearningmastery.com/gentle-introduction-autocorrelation-partial-autocorrelation/)

# %%
import statsmodels.api as sm

# %%
dta = sm.datasets.sunspots.load_pandas().data
dta.index = pd.Index(sm.tsa.datetools.dates_from_range('1700', '2008'))
del dta["YEAR"]
sm.graphics.tsa.plot_acf(dta.values.squeeze(), lags = 40)
plt.show()

# %%
serie_casos_novos_sp = dados_sp['casos_novos']
serie_casos_novos_sp.plot()
plt.show()

# %% [markdown]
# ### DESAFIO 03.01.07: Mover o número de obitos alguns dias para verificar se a relação entre os casos novos e os óbitos. Teste diferentes janelas de tempo (3 dias, 7 dias, 14 dias)
# ### DESAFIO 03.01.08: Calcular a função de autocorrelação cruzada dos óbitos e casos. (teste a biblioteca statsmodels)
# ### DESAFIO 03.01.09: Estudar todos esses padrões para outro município e comparar com o município de São Paulo.

# %% [markdown]
# ### O que aprendemos?

# %% [markdown]
# ## AULA 02 - Primeiras previsões com o Prophet

# %% [markdown]
# **Preparando para forcast com o Prophet.**
# **Documentação consultada:**
# - [Pip Install fbprophet](https://pypi.org/project/fbprophet/)
# - [Prophet QuickStart](https://facebook.github.io/prophet/docs/quick_start.html)

# %%
df = pd.DataFrame()

# %%
df['ds'] = dados_sp['datahora'][:400]

# %%
df['y'] = dados_sp['casos_novos'][:400]

# %%
dados_sp.shape
# Out:
# (443, 31)

# %%
from fbprophet import Prophet

# %%
modelo = Prophet()

# %%
modelo.fit(df)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
dataframefuturo = modelo.make_future_dataframe(periods=43)

# %%
dataframefuturo.head()
# Out:
#           ds
# 0 2020-02-25
# 1 2020-02-26
# 2 2020-02-27
# 3 2020-02-28
# 4 2020-02-29

# %%
previsao = modelo.predict(dataframefuturo)

# %%
previsao.head()
# Out:
#           ds       trend   yhat_lower   yhat_upper  trend_lower  trend_upper  \
# 0 2020-02-25 -144.473695  -756.700099  1271.313375  -144.473695  -144.473695
# 1 2020-02-26 -126.671483  -832.931411  1340.221627  -126.671483  -126.671483
# 2 2020-02-27 -108.869271  -618.790328  1524.100880  -108.869271  -108.869271
# 3 2020-02-28  -91.067059  -766.361503  1269.211693   -91.067059   -91.067059
# 4 2020-02-29  -73.264847 -1134.929130  1035.428325   -73.264847   -73.264847
#
#    additive_terms  additive_terms_lower  additive_terms_upper      weekly  \
# 0      458.701931            458.701931            458.701931  458.701931
# 1      458.079045            458.079045            458.079045  458.079045
# 2      597.622320            597.622320            597.622320  597.622320
# 3      341.665155            341.665155            341.665155  341.665155
# 4       59.273342             59.273342             59.273342   59.273342
#
#    weekly_lower  weekly_upper  multiplicative_terms  \
# 0    458.701931    458.701931                   0.0
# 1    458.079045    458.079045                   0.0
# 2    597.622320    597.622320                   0.0
# 3    341.665155    341.665155                   0.0
# 4     59.273342     59.273342                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper        yhat
# 0                         0.0                         0.0  314.228236
# 1                         0.0                         0.0  331.407562
# 2                         0.0                         0.0  488.753049
# 3                         0.0                         0.0  250.598096
# 4                         0.0                         0.0  -13.991505

# %%
df_teste = pd.DataFrame()
df_teste['ds'] = dados_sp['datahora'][400:]
df_teste['y'] = dados_sp['casos_novos'][400:]

# %%
modelo.plot(previsao, xlabel = 'Data', ylabel='Casos Novos', figsize=(20,10));
plt.plot(df_teste['ds'],df_teste['y'],'.r')

# %%
modelo.plot_components(previsao, figsize=(15,5));

# %% [markdown]
# ### DESAFIO 08: Mudar os períodos de previsão. Testar vários números de dias e ver os resultados de previsão.
#
# ### DESAFIO 09: Checar a documentação do Prophet e o repositório do GitHub desse projeto. Checar particularmente o "Quick Start". Melhorar os gráficos: incluir títulos, nomes dos eixos, indicações dos ticks de inglês para português.

# %% [markdown]
# ## AULA 03 - Mudança de tendência

# %%
from fbprophet.plot import add_changepoints_to_plot

# %%
fig = modelo.plot(previsao, figsize=(15,10))
a = add_changepoints_to_plot(fig.gca(), modelo, previsao)

# %% [markdown]
# ### DESAFIO 10: Fazer todo o processo de previsão para o número de casos acumulados. (Utilizando o método Growth do Prophet) Aproveitar para pesquisar os termos da estatística mencionados: sigmoide, regressão logística, curva logística, crescimento logístico.

# %%
modelo = Prophet(n_changepoints=25, changepoint_prior_scale=10.0)
#modelo = Prophet(changepoints=['2020-06-30','2020-12-31'])

# %%
modelo.add_country_holidays(country_name='BR')

# %%
modelo.fit(df)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
dataframefuturo = modelo.make_future_dataframe(periods=43)

# %%
previsao = modelo.predict(dataframefuturo)

# %% [markdown]
# ### DESAFIO 11: Identificar potenciais changepoints a partir do gráfico de barras gerado nas primeiras aulas do curso.
#     - Adicionar changepoints específicos;
#     - Checar cuidadosamente a documentação do Prophet.
#
# ### DESAFIO 12: Desenvolver uma função que roda o modelo automaticamente as partes repetidas do código.

# %% [markdown]
# ## AULA 04 - Feriados e Sazonalidade

# %% [markdown]
# #### Feriados

# %%
fig = modelo.plot(previsao, figsize=(15,10))

# %%
feriados_sp_2020= [
'2020-02-25',
'2020-02-26',
'2020-04-10',
'2020-04-21',
'2020-05-01',
'2020-05-20',
'2020-05-21',
'2020-05-22',
'2020-05-25',
'2020-06-11',
'2020-09-07',
'2020-10-12',
'2020-11-02',
'2020-11-15',
'2020-12-25'
]

feriados_sp_2021= [
'2021-01-01',
'2021-01-25',
'2021-02-15',
'2021-02-16',
'2021-02-17',
'2021-03-26',
'2021-03-29',
'2021-03-30',
'2021-03-31',
'2021-04-01',
'2021-04-02',
'2021-4-21',
'2021-05-01'
]

# %%
feriados_sp_2020 = pd.DataFrame({'holiday': 'sp_2020',
                                'ds': pd.to_datetime(feriados_sp_2020)})

# %%
feriados_sp_2021 = pd.DataFrame({'holiday': 'sp_2021',
                                'ds': pd.to_datetime(feriados_sp_2021)})

# %%
feriados = pd.concat((feriados_sp_2020, feriados_sp_2021))

# %%
feriados
# Out:
#     holiday         ds
# 0   sp_2020 2020-02-25
# 1   sp_2020 2020-02-26
# 2   sp_2020 2020-04-10
# 3   sp_2020 2020-04-21
# 4   sp_2020 2020-05-01
# 5   sp_2020 2020-05-20
# 6   sp_2020 2020-05-21
# 7   sp_2020 2020-05-22
# 8   sp_2020 2020-05-25
# 9   sp_2020 2020-06-11
# 10  sp_2020 2020-09-07
# 11  sp_2020 2020-10-12
# 12  sp_2020 2020-11-02
# 13  sp_2020 2020-11-15
# 14  sp_2020 2020-12-25
# 0   sp_2021 2021-01-01
# 1   sp_2021 2021-01-25
# 2   sp_2021 2021-02-15
# 3   sp_2021 2021-02-16
# 4   sp_2021 2021-02-17
# 5   sp_2021 2021-03-26
# 6   sp_2021 2021-03-29
# 7   sp_2021 2021-03-30
# 8   sp_2021 2021-03-31
# 9   sp_2021 2021-04-01
# 10  sp_2021 2021-04-02
# 11  sp_2021 2021-04-21
# 12  sp_2021 2021-05-01

# %%
modelo_feriados = Prophet(changepoint_prior_scale=10.0, holidays=feriados, seasonality_mode='multiplicative')

# %%
modelo_feriados.fit(df)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
dataframefuturo = modelo_feriados.make_future_dataframe(periods=43)

# %%
previsao = modelo_feriados.predict(dataframefuturo)

# %%
fig = modelo.plot(previsao, figsize=(15,10))
plt.plot(df_teste['ds'],df_teste['y'],'.r')

# %%
modelo_feriados.plot_components(previsao, figsize = (15,10));

# %% [markdown]
# #### Sazonalidade

# %%
from sklearn.metrics import mean_absolute_error

# %%
#Sazonalidade Aditiva

mean_absolute_error(df['y'], previsao['yhat'][:400])
# Out:
# 536.6350479377263

# %%
#Sazonalidade Multiplicativa

mean_absolute_error(df['y'], previsao['yhat'][:400])
# Out:
# 452.32061867205294

# %% [markdown]
# ### DESAFIO 11: Substituir os pontos do gráfico por uma linha para comparar com as oscilações de sazonalidade.

# %% [markdown]
# ### O que aprendemos?
